# %%
# %matplotlib inline

# %%
# Dependencies and Setup

import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
# Read Purchasing File and store into Pandas data frame
fire_data = pd.read_csv("Resources/fire_Final.csv")

fire_data
# Out:
#         OBJECTID   STAT_CAUSE_DESCR STATE Date_Discovery Date_Contained  \
# 0              1      Miscellaneous    CA       2/2/2005       2/2/2005
# 1              2          Lightning    CA      5/12/2004      5/12/2004
# 2              3     Debris Burning    CA      5/31/2004      5/31/2004
# 3              4          Lightning    CA      6/28/2004       7/3/2004
# 4              5          Lightning    CA      6/28/2004       7/3/2004
# 5              6          Lightning    CA      6/30/2004       7/1/2004
# 6              7          Lightning    CA       7/1/2004       7/2/2004
# 7              8     Debris Burning    CA       3/8/2005       3/8/2005
# 8              9     Debris Burning    CA      3/15/2005      3/15/2005
# 9             10          Lightning    CA       7/1/2004       7/2/2004
# 10            11          Lightning    CA       7/2/2004       7/3/2004
# 11            12          Lightning    CA       7/2/2004       7/3/2004
# ...

# %%
fig, ax = plt.subplots()
fire_data.groupby('FIRE_YEAR')["OBJECTID"].nunique().plot(kind='bar', figsize=(10,10), title = "Total Fire Count by Year")

plt.savefig('data/total_Fires_Chart_By_Year.png')

#fire_data.groupby(["FIRE_YEAR"])
#fire_year_df= fire_year["OBJECTID"].nunique()

# %% [raw]
# fig, ax = plt.subplots()
#
# fire_year_df.plot.bar(title = "total Fires Per Year all States")
# plt.savefig('data/total_Fires_Chart_By_Year.png')

# %%
# File to Load 
file_to_load = "CAFireData.csv"

# Read Purchasing File and store into Pandas data frame
fire_CA = pd.read_csv(file_to_load)

fire_CA.groupby('FIRE_YEAR')["OBJECTID"].nunique().plot(kind='bar', figsize=(10,10), title = "Total Fire Count by Year California")

plt.savefig('data/total_Fires_Chart_By_Year_CA.png')

# %%
# File to Load 
file_to_load = "GAFireData.csv"

# Read Purchasing File and store into Pandas data frame
fire_GA = pd.read_csv(file_to_load)


fire_GA.groupby('FIRE_YEAR')["OBJECTID"].nunique().plot(kind='bar', figsize=(10,10), title = "Total Fire Count by Year Georgia")

plt.savefig('data/total_Fires_Chart_By_Year_GA.png')

# %%
# File to Load 
file_to_load = "WAFireData.csv"

# Read Purchasing File and store into Pandas data frame
fire_WA = pd.read_csv(file_to_load)

fire_WA.groupby('FIRE_YEAR')["OBJECTID"].nunique().plot(kind='bar', figsize=(10,10), title = "Total Fire Count by Year Washinton")

plt.savefig('data/total_Fires_Chart_By_Year_WA.png')
# Out:
#   File "<ipython-input-33-567b09801fae>", line 7
#     fire_WA.groupby('FIRE_YEAR')["OBJECTID"].nunique().plot(kind='bar',explode= 1 figsize=(10,10), title = "Total Fire Count by Year Washinton")
#                                                                                         ^
# SyntaxError: invalid syntax

# %%
fire_WA.groupby('STAT_CAUSE_DESCR')["OBJECTID"].nunique().plot(kind='pie', figsize=(10,10), title = "Causes of Fire in washington",autopct='%1.1f%%')

plt.savefig('data/Fire-Cause-WA.png')

# %%
fire_CA.groupby('STAT_CAUSE_DESCR')["OBJECTID"].nunique().plot(kind='pie', figsize=(10,10), title = "Causes of Fire in California",autopct='%1.1f%%')

plt.savefig('data/Fire-Cause-CA.png')

# %%
fire_GA.groupby('STAT_CAUSE_DESCR')["OBJECTID"].nunique().plot(kind='pie', figsize=(10,10), title = "Causes of Fire in Georgia",autopct='%1.1f%%')

plt.savefig('data/Fire-Cause-GA.png')

# %%
fire_OR = pd.read_csv("ORFireData.csv")

# %%
fire_OR.groupby('STAT_CAUSE_DESCR')["OBJECTID"].nunique().plot(kind='pie', figsize=(10,10), title = "Causes of Fire in Oregon",autopct='%1.1f%%')

plt.savefig('data/Fire-Cause-OR.png')
